# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
import os

num_skipped = 0
for folder_name in ("1c", "1e","2c", "2e","10c", "20c","50c"):
    folder_path = os.path.join("new_extended_dataset/original", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %%
batch_size=64   
target_size = 200

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "new_extended_dataset/original",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=(target_size,target_size),
    batch_size=batch_size,
)
# Out:
# Found 9664 files belonging to 8 classes.
# Using 7732 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "new_extended_dataset/original",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=(target_size,target_size),
    batch_size=batch_size,
)
# Out:
# Found 9664 files belonging to 8 classes.
# Using 1932 files for validation.

# %%
data_augmentation = keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomContrast(factor=0.5),
])

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %% [markdown]
# Modelbuilding

# %%
inputs = keras.Input(shape=(target_size,target_size, 3))

x = data_augmentation(inputs)

x = layers.Rescaling(1.0 / 255)(x)

x = layers.Conv2D(filters=16, kernel_size=3, strides=2, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(filters=32, kernel_size=3, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)

previous_block_activation = x  # Set aside residual

for n_filters in [64, 128, 256, 512, 728]:
    x = layers.Conv2D(filters=n_filters, kernel_size=3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=n_filters, kernel_size=3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D(pool_size=3, strides=2, padding="same")(x)

    # Project residual
    residual = layers.Conv2D(n_filters, 1, strides=2, padding="same")(previous_block_activation)
    x = layers.add([x, residual])  # Add back residual
    previous_block_activation = x  # Set aside next residual


x = layers.Conv2D(filters=1024, kernel_size=3, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)


x = layers.SpatialDropout2D(0.5)(x)
#Flatten hat in den vorherigen Modellen bessere Ergebnisse erzeugt
#x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)

outputs = layers.Dense(8, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 200, 200, 3)  0           ['input_8[0][0]']
#
#  rescaling_7 (Rescaling)        (None, 200, 200, 3)  0           ['sequential[7][0]']
#
#  conv2d_126 (Conv2D)            (None, 100, 100, 16  448         ['rescaling_7[0][0]']
#                                 )
#
#  batch_normalization_91 (BatchN  (None, 100, 100, 16  64         ['conv2d_126[0][0]']
#  ormalization)                  )
#
#  conv2d_127 (Conv2D)            (None, 100, 100, 32  4640        ['batch_normalization_91[0][0]']
#                                 )
#
#  batch_normalization_92 (BatchN  (None, 100, 100, 32  128        ['conv2d_127[0][0]']
#  ormalization)                  )
#
#  conv2d_128 (Conv2D)            (None, 100, 100, 64  18496       ['batch_normalization_92[0][0]']
#                                 )
#
#  batch_normalization_93 (BatchN  (None, 100, 100, 64  256        ['conv2d_128[0][0]']
#  ormalization)                  )
#
#  conv2d_129 (Conv2D)            (None, 100, 100, 64  36928       ['batch_normalization_93[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 100, 100, 64  256        ['conv2d_129[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_35 (MaxPooling2D  (None, 50, 50, 64)  0           ['batch_normalization_94[0][0]']
#  )
#
#  conv2d_130 (Conv2D)            (None, 50, 50, 64)   2112        ['batch_normalization_92[0][0]']
#
#  add_35 (Add)                   (None, 50, 50, 64)   0           ['max_pooling2d_35[0][0]',
#                                                                   'conv2d_130[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 50, 50, 128)  73856       ['add_35[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 50, 50, 128)  512        ['conv2d_131[0][0]']
#  ormalization)
#
#  conv2d_132 (Conv2D)            (None, 50, 50, 128)  147584      ['batch_normalization_95[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 50, 50, 128)  512        ['conv2d_132[0][0]']
#  ormalization)
#
#  max_pooling2d_36 (MaxPooling2D  (None, 25, 25, 128)  0          ['batch_normalization_96[0][0]']
#  )
#
#  conv2d_133 (Conv2D)            (None, 25, 25, 128)  8320        ['add_35[0][0]']
#
#  add_36 (Add)                   (None, 25, 25, 128)  0           ['max_pooling2d_36[0][0]',
#                                                                   'conv2d_133[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 25, 25, 256)  295168      ['add_36[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 25, 25, 256)  1024       ['conv2d_134[0][0]']
#  ormalization)
#
#  conv2d_135 (Conv2D)            (None, 25, 25, 256)  590080      ['batch_normalization_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 25, 25, 256)  1024       ['conv2d_135[0][0]']
#  ormalization)
#
#  max_pooling2d_37 (MaxPooling2D  (None, 13, 13, 256)  0          ['batch_normalization_98[0][0]']
#  )
#
#  conv2d_136 (Conv2D)            (None, 13, 13, 256)  33024       ['add_36[0][0]']
#
#  add_37 (Add)                   (None, 13, 13, 256)  0           ['max_pooling2d_37[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 13, 13, 512)  1180160     ['add_37[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 13, 13, 512)  2048       ['conv2d_137[0][0]']
#  ormalization)
#
#  conv2d_138 (Conv2D)            (None, 13, 13, 512)  2359808     ['batch_normalization_99[0][0]']
#
#  batch_normalization_100 (Batch  (None, 13, 13, 512)  2048       ['conv2d_138[0][0]']
#  Normalization)
#
#  max_pooling2d_38 (MaxPooling2D  (None, 7, 7, 512)   0           ['batch_normalization_100[0][0]']
#  )
#
#  conv2d_139 (Conv2D)            (None, 7, 7, 512)    131584      ['add_37[0][0]']
#
#  add_38 (Add)                   (None, 7, 7, 512)    0           ['max_pooling2d_38[0][0]',
#                                                                   'conv2d_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 7, 7, 728)    3355352     ['add_38[0][0]']
#
#  batch_normalization_101 (Batch  (None, 7, 7, 728)   2912        ['conv2d_140[0][0]']
#  Normalization)
#
#  conv2d_141 (Conv2D)            (None, 7, 7, 728)    4770584     ['batch_normalization_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 7, 7, 728)   2912        ['conv2d_141[0][0]']
#  Normalization)
#
#  max_pooling2d_39 (MaxPooling2D  (None, 4, 4, 728)   0           ['batch_normalization_102[0][0]']
#  )
#
#  conv2d_142 (Conv2D)            (None, 4, 4, 728)    373464      ['add_38[0][0]']
#
#  add_39 (Add)                   (None, 4, 4, 728)    0           ['max_pooling2d_39[0][0]',
#                                                                   'conv2d_142[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 4, 4, 1024)   6710272     ['add_39[0][0]']
#
#  batch_normalization_103 (Batch  (None, 4, 4, 1024)  4096        ['conv2d_143[0][0]']
#  Normalization)
#
#  spatial_dropout2d_6 (SpatialDr  (None, 4, 4, 1024)  0           ['batch_normalization_103[0][0]']
#  opout2D)
#
#  flatten_5 (Flatten)            (None, 16384)        0           ['spatial_dropout2d_6[0][0]']
#
#  dense_5 (Dense)                (None, 8)            131080      ['flatten_5[0][0]']
#
# ==================================================================================================
# Total params: 20,240,752
# Trainable params: 20,231,856
# Non-trainable params: 8,896
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("Models/advance_model/save_at_{epoch}.h5"),
    keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0.01, patience=3)
]

# %%
#'categorical_crossentropy' works on one-hot encoded target, while 'sparse_categorical_crossentropy' works on integer target.
model.compile(optimizer="adam",
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %% [markdown]
# Model training

# %%
epochs=50

history = model.fit(
    train_ds, 
    epochs=epochs, 
    callbacks=callbacks, 
    validation_data=val_ds,
)
# Out:
# Epoch 1/50
# 120/120 [==============================] - 122s 1s/step - loss: 1.3068 - accuracy: 0.4587 - val_loss: 1.8209 - val_accuracy: 0.4025
# Epoch 2/50
# 120/120 [==============================] - 116s 970ms/step - loss: 0.8143 - accuracy: 0.6385 - val_loss: 2.0356 - val_accuracy: 0.4250
# Epoch 3/50
# 120/120 [==============================] - 116s 971ms/step - loss: 0.7018 - accuracy: 0.7001 - val_loss: 2.3679 - val_accuracy: 0.4930
# Epoch 4/50
# 120/120 [==============================] - 116s 969ms/step - loss: 0.5895 - accuracy: 0.7524 - val_loss: 1.9564 - val_accuracy: 0.5086
# Epoch 5/50
# 120/120 [==============================] - 117s 974ms/step - loss: 0.4712 - accuracy: 0.8089 - val_loss: 2.3587 - val_accuracy: 0.5011
# Epoch 6/50
# 120/120 [==============================] - 125s 1s/step - loss: 0.4142 - accuracy: 0.8366 - val_loss: 2.4615 - val_accuracy: 0.5552
# Epoch 7/50
# 120/120 [==============================] - 129s 1s/step - loss: 0.3596 - accuracy: 0.8649 - val_loss: 2.1556 - val_accuracy: 0.5798
# Epoch 8/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.2846 - accuracy: 0.8939 - val_loss: 1.6813 - val_accuracy: 0.5986
# Epoch 9/50
# 120/120 [==============================] - 117s 973ms/step - loss: 0.2644 - accuracy: 0.9040 - val_loss: 2.5497 - val_accuracy: 0.5970
# Epoch 10/50
# 120/120 [==============================] - 117s 977ms/step - loss: 0.2465 - accuracy: 0.9100 - val_loss: 1.3506 - val_accuracy: 0.6238
# Epoch 11/50
# 120/120 [==============================] - 117s 972ms/step - loss: 0.2192 - accuracy: 0.9216 - val_loss: 2.5347 - val_accuracy: 0.6415
# Epoch 12/50
# 120/120 [==============================] - 117s 975ms/step - loss: 0.1910 - accuracy: 0.9323 - val_loss: 2.7942 - val_accuracy: 0.6442
# Epoch 13/50
# 120/120 [==============================] - 116s 969ms/step - loss: 0.1573 - accuracy: 0.9435 - val_loss: 2.4702 - val_accuracy: 0.6356
# Epoch 14/50
# 120/120 [==============================] - 116s 970ms/step - loss: 0.1382 - accuracy: 0.9519 - val_loss: 2.5732 - val_accuracy: 0.6742
# Epoch 15/50
# 120/120 [==============================] - 138s 1s/step - loss: 0.1565 - accuracy: 0.9447 - val_loss: 3.1435 - val_accuracy: 0.6141
# Epoch 16/50
# 120/120 [==============================] - 177s 1s/step - loss: 0.1451 - accuracy: 0.9498 - val_loss: 1.6904 - val_accuracy: 0.6484
# Epoch 17/50
# 120/120 [==============================] - 213s 2s/step - loss: 0.1225 - accuracy: 0.9533 - val_loss: 3.0541 - val_accuracy: 0.6447
# Epoch 18/50
# 120/120 [==============================] - 190s 2s/step - loss: 0.1005 - accuracy: 0.9654 - val_loss: 2.9586 - val_accuracy: 0.6308
# Epoch 19/50
# 120/120 [==============================] - 171s 1s/step - loss: 0.1152 - accuracy: 0.9587 - val_loss: 2.0037 - val_accuracy: 0.7117
# Epoch 20/50
# 120/120 [==============================] - 169s 1s/step - loss: 0.0901 - accuracy: 0.9708 - val_loss: 3.1737 - val_accuracy: 0.6533
# Epoch 21/50
# 120/120 [==============================] - 165s 1s/step - loss: 0.0815 - accuracy: 0.9704 - val_loss: 2.5034 - val_accuracy: 0.6924
# Epoch 22/50
# 120/120 [==============================] - 170s 1s/step - loss: 0.0795 - accuracy: 0.9711 - val_loss: 2.0979 - val_accuracy: 0.7042
# Epoch 23/50
# 120/120 [==============================] - 160s 1s/step - loss: 0.0926 - accuracy: 0.9695 - val_loss: 1.9297 - val_accuracy: 0.6844
# Epoch 24/50
# 120/120 [==============================] - 159s 1s/step - loss: 0.0912 - accuracy: 0.9677 - val_loss: 1.5182 - val_accuracy: 0.7192
# Epoch 25/50
# 120/120 [==============================] - 162s 1s/step - loss: 0.0687 - accuracy: 0.9772 - val_loss: 2.5771 - val_accuracy: 0.7133
# Epoch 26/50
# 120/120 [==============================] - 153s 1s/step - loss: 0.1005 - accuracy: 0.9653 - val_loss: 2.8010 - val_accuracy: 0.6779
# Epoch 27/50
# 120/120 [==============================] - 162s 1s/step - loss: 0.0659 - accuracy: 0.9773 - val_loss: 3.1146 - val_accuracy: 0.6913
# Epoch 28/50
# 120/120 [==============================] - 179s 1s/step - loss: 0.0621 - accuracy: 0.9797 - val_loss: 2.3412 - val_accuracy: 0.6929
# Epoch 29/50
# 120/120 [==============================] - 174s 1s/step - loss: 0.0697 - accuracy: 0.9754 - val_loss: 2.3214 - val_accuracy: 0.6902
# Epoch 30/50
# 120/120 [==============================] - 182s 2s/step - loss: 0.0628 - accuracy: 0.9793 - val_loss: 1.5242 - val_accuracy: 0.7358
# Epoch 31/50
# 120/120 [==============================] - 173s 1s/step - loss: 0.0557 - accuracy: 0.9793 - val_loss: 3.2074 - val_accuracy: 0.7219
# Epoch 32/50
# 120/120 [==============================] - 175s 1s/step - loss: 0.1537 - accuracy: 0.9546 - val_loss: 2.1585 - val_accuracy: 0.7106
# Epoch 33/50
# 120/120 [==============================] - 148s 1s/step - loss: 0.0550 - accuracy: 0.9820 - val_loss: 1.7797 - val_accuracy: 0.7411
# Epoch 34/50
# 120/120 [==============================] - 117s 971ms/step - loss: 0.0422 - accuracy: 0.9867 - val_loss: 2.3391 - val_accuracy: 0.7197
# Epoch 35/50
# 120/120 [==============================] - 117s 972ms/step - loss: 0.0551 - accuracy: 0.9824 - val_loss: 1.7453 - val_accuracy: 0.7106
# Epoch 36/50
# 120/120 [==============================] - 117s 973ms/step - loss: 0.0505 - accuracy: 0.9817 - val_loss: 1.6285 - val_accuracy: 0.7294
# Epoch 37/50
# 120/120 [==============================] - 117s 973ms/step - loss: 0.0643 - accuracy: 0.9763 - val_loss: 1.7254 - val_accuracy: 0.7262
# Epoch 38/50
# 120/120 [==============================] - 117s 973ms/step - loss: 0.0497 - accuracy: 0.9823 - val_loss: 2.5981 - val_accuracy: 0.7288
# Epoch 39/50
# 120/120 [==============================] - 116s 971ms/step - loss: 0.0581 - accuracy: 0.9828 - val_loss: 1.6257 - val_accuracy: 0.7251
# Epoch 40/50
# 120/120 [==============================] - 116s 971ms/step - loss: 0.0414 - accuracy: 0.9860 - val_loss: 1.7904 - val_accuracy: 0.7406
# Epoch 41/50
# 120/120 [==============================] - 117s 972ms/step - loss: 0.0591 - accuracy: 0.9795 - val_loss: 2.4993 - val_accuracy: 0.7149
# Epoch 42/50
# 120/120 [==============================] - 116s 970ms/step - loss: 0.0516 - accuracy: 0.9806 - val_loss: 1.6724 - val_accuracy: 0.7353
# Epoch 43/50
# 120/120 [==============================] - 116s 968ms/step - loss: 0.0464 - accuracy: 0.9829 - val_loss: 1.4208 - val_accuracy: 0.7706
# Epoch 44/50
# 120/120 [==============================] - 128s 1s/step - loss: 0.0438 - accuracy: 0.9855 - val_loss: 1.6596 - val_accuracy: 0.7535
# Epoch 45/50
# 120/120 [==============================] - 122s 1s/step - loss: 0.0477 - accuracy: 0.9814 - val_loss: 1.8022 - val_accuracy: 0.7438
# Epoch 46/50
# 120/120 [==============================] - 122s 1s/step - loss: 0.0456 - accuracy: 0.9847 - val_loss: 1.8899 - val_accuracy: 0.7610
# Epoch 47/50
# 120/120 [==============================] - 121s 1s/step - loss: 0.0432 - accuracy: 0.9864 - val_loss: 1.5732 - val_accuracy: 0.7910
# Epoch 48/50
# 120/120 [==============================] - 119s 991ms/step - loss: 0.0523 - accuracy: 0.9819 - val_loss: 1.4926 - val_accuracy: 0.7712
# Epoch 49/50
# 120/120 [==============================] - 116s 968ms/step - loss: 0.0415 - accuracy: 0.9868 - val_loss: 1.2650 - val_accuracy: 0.7824
# Epoch 50/50
# 120/120 [==============================] - 116s 969ms/step - loss: 0.0767 - accuracy: 0.9748 - val_loss: 1.5860 - val_accuracy: 0.7567

# %%
epochs_range = range(epochs)

plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')

# %% [markdown]
# Safe and Load Model
#
# https://www.tensorflow.org/guide/keras/save_and_serialize

# %%
model.save('Models/maxConv2D_512_Flatten_50/extended_data_set')
# Out:
# INFO:tensorflow:Assets written to: Models/maxConv2D_512_Flatten_50/extended_data_set\assets
