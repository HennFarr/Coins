# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
import os

num_skipped = 0
for folder_name in ("1c", "1e","2c", "2e","10c", "20c","50c"):
    folder_path = os.path.join("new_extended_dataset/original", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %%
batch_size=64   
target_size = 200

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "new_extended_dataset/original",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=(target_size,target_size),
    batch_size=batch_size,
)
# Out:
# Found 9664 files belonging to 8 classes.
# Using 7732 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "new_extended_dataset/original",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=(target_size,target_size),
    batch_size=batch_size,
)
# Out:
# Found 9664 files belonging to 8 classes.
# Using 1932 files for validation.

# %%
data_augmentation = keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomContrast(factor=0.5),
])

# %%
train_ds = train_ds.prefetch(buffer_size=64)
val_ds = val_ds.prefetch(buffer_size=64)

# %% [markdown]
# Modelbuilding

# %%
inputs = keras.Input(shape=(target_size,target_size, 3))

x = data_augmentation(inputs)

x = layers.Rescaling(1.0 / 255)(x)

x = layers.Conv2D(filters=16, kernel_size=3, strides=2, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(filters=32, kernel_size=3, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)

previous_block_activation = x  # Set aside residual

for n_filters in [64, 128, 256, 512]:
    x = layers.Conv2D(filters=n_filters, kernel_size=3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=n_filters, kernel_size=3, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D(pool_size=3, strides=2, padding="same")(x)

    # Project residual
    residual = layers.Conv2D(n_filters, 1, strides=2, padding="same")(previous_block_activation)
    x = layers.add([x, residual])  # Add back residual
    previous_block_activation = x  # Set aside next residual


x = layers.Conv2D(filters=728, kernel_size=3, padding="same", activation="relu")(x)
x = layers.BatchNormalization()(x)


x = layers.SpatialDropout2D(0.5)(x)
#Flatten hat in den vorherigen Modellen bessere Ergebnisse erzeugt
#x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)

outputs = layers.Dense(8, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 200, 200, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 200, 200, 3)  0           ['input_12[0][0]']
#
#  rescaling_11 (Rescaling)       (None, 200, 200, 3)  0           ['sequential[11][0]']
#
#  conv2d_188 (Conv2D)            (None, 100, 100, 16  448         ['rescaling_11[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 100, 100, 16  64         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  conv2d_189 (Conv2D)            (None, 100, 100, 32  4640        ['batch_normalization_136[0][0]']
#                                 )
#
#  batch_normalization_137 (Batch  (None, 100, 100, 32  128        ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  conv2d_190 (Conv2D)            (None, 100, 100, 64  18496       ['batch_normalization_137[0][0]']
#                                 )
#
#  batch_normalization_138 (Batch  (None, 100, 100, 64  256        ['conv2d_190[0][0]']
#  Normalization)                 )
#
#  conv2d_191 (Conv2D)            (None, 100, 100, 64  36928       ['batch_normalization_138[0][0]']
#                                 )
#
#  batch_normalization_139 (Batch  (None, 100, 100, 64  256        ['conv2d_191[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_52 (MaxPooling2D  (None, 50, 50, 64)  0           ['batch_normalization_139[0][0]']
#  )
#
#  conv2d_192 (Conv2D)            (None, 50, 50, 64)   2112        ['batch_normalization_137[0][0]']
#
#  add_52 (Add)                   (None, 50, 50, 64)   0           ['max_pooling2d_52[0][0]',
#                                                                   'conv2d_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 50, 50, 128)  73856       ['add_52[0][0]']
#
#  batch_normalization_140 (Batch  (None, 50, 50, 128)  512        ['conv2d_193[0][0]']
#  Normalization)
#
#  conv2d_194 (Conv2D)            (None, 50, 50, 128)  147584      ['batch_normalization_140[0][0]']
#
#  batch_normalization_141 (Batch  (None, 50, 50, 128)  512        ['conv2d_194[0][0]']
#  Normalization)
#
#  max_pooling2d_53 (MaxPooling2D  (None, 25, 25, 128)  0          ['batch_normalization_141[0][0]']
#  )
#
#  conv2d_195 (Conv2D)            (None, 25, 25, 128)  8320        ['add_52[0][0]']
#
#  add_53 (Add)                   (None, 25, 25, 128)  0           ['max_pooling2d_53[0][0]',
#                                                                   'conv2d_195[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 25, 25, 256)  295168      ['add_53[0][0]']
#
#  batch_normalization_142 (Batch  (None, 25, 25, 256)  1024       ['conv2d_196[0][0]']
#  Normalization)
#
#  conv2d_197 (Conv2D)            (None, 25, 25, 256)  590080      ['batch_normalization_142[0][0]']
#
#  batch_normalization_143 (Batch  (None, 25, 25, 256)  1024       ['conv2d_197[0][0]']
#  Normalization)
#
#  max_pooling2d_54 (MaxPooling2D  (None, 13, 13, 256)  0          ['batch_normalization_143[0][0]']
#  )
#
#  conv2d_198 (Conv2D)            (None, 13, 13, 256)  33024       ['add_53[0][0]']
#
#  add_54 (Add)                   (None, 13, 13, 256)  0           ['max_pooling2d_54[0][0]',
#                                                                   'conv2d_198[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 13, 13, 512)  1180160     ['add_54[0][0]']
#
#  batch_normalization_144 (Batch  (None, 13, 13, 512)  2048       ['conv2d_199[0][0]']
#  Normalization)
#
#  conv2d_200 (Conv2D)            (None, 13, 13, 512)  2359808     ['batch_normalization_144[0][0]']
#
#  batch_normalization_145 (Batch  (None, 13, 13, 512)  2048       ['conv2d_200[0][0]']
#  Normalization)
#
#  max_pooling2d_55 (MaxPooling2D  (None, 7, 7, 512)   0           ['batch_normalization_145[0][0]']
#  )
#
#  conv2d_201 (Conv2D)            (None, 7, 7, 512)    131584      ['add_54[0][0]']
#
#  add_55 (Add)                   (None, 7, 7, 512)    0           ['max_pooling2d_55[0][0]',
#                                                                   'conv2d_201[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 7, 7, 728)    3355352     ['add_55[0][0]']
#
#  batch_normalization_146 (Batch  (None, 7, 7, 728)   2912        ['conv2d_202[0][0]']
#  Normalization)
#
#  spatial_dropout2d_10 (SpatialD  (None, 7, 7, 728)   0           ['batch_normalization_146[0][0]']
#  ropout2D)
#
#  flatten_9 (Flatten)            (None, 35672)        0           ['spatial_dropout2d_10[0][0]']
#
#  dense_9 (Dense)                (None, 8)            285384      ['flatten_9[0][0]']
#
# ==================================================================================================
# Total params: 8,533,728
# Trainable params: 8,528,336
# Non-trainable params: 5,392
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("Models/advance_model/save_at_{epoch}.h5"),
    keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0.01, patience=3)
]

# %%
#'categorical_crossentropy' works on one-hot encoded target, while 'sparse_categorical_crossentropy' works on integer target.
model.compile(optimizer="adam",
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %% [markdown]
# Model training

# %%
epochs=50

history = model.fit(
    train_ds, 
    epochs=epochs, 
    callbacks=callbacks, 
    validation_data=val_ds,
)
# Out:
# Epoch 1/50
#  10/121 [=>............................] - ETA: 13:09 - loss: 8.7302 - accuracy: 0.2672
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7172\276319489.py in <cell line: 3>()
#       1 epochs=50
#       2
# ----> 3 history = model.fit(
#       4     train_ds,
#       5     epochs=epochs,
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# c:\Users\henni\anaconda3\envs\tf\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
epochs_range = range(epochs)

plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')

# %% [markdown]
# Safe and Load Model
#
# https://www.tensorflow.org/guide/keras/save_and_serialize

# %%
model.save('Models/maxConv2D_512_Flatten_50/extended_data_set')
# Out:
# INFO:tensorflow:Assets written to: Models/maxConv2D_512_Flatten_50/extended_data_set\assets
